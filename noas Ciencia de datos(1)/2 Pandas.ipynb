# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('master.csv',index_col=[0]) 
# df['edad']
df
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5      Edgar Pons             Robótica    29   143620    H
# 6         s4vitar              Hacking    28   132567    H

# %%
datos= {
    'nombre' : list(df['nombre']),
    'especialidad' : list(df['especialidad']),
    'edad': [np.random.randint(28,35) for i in range(len(df['edad']))],
    'visistas': [np.random.randint(10000,35000) for i in range(len(df['edad']))],
}

# %%
df_=pd.DataFrame(datos)
df_
# Out:
#            nombre         especialidad  edad  visistas
# 0       SFDX Show             Hardware    33     14610
# 1     Sara Nogark     Edición de vídeo    32     23135
# 2    Nate Gentile         Programación    30     14429
# 3       Bettatech         Programación    33     20531
# 4  Antonio Sarosi  Sistemas Operativos    28     34024
# 5      Edgar Pons             Robótica    28     28923
# 6         s4vitar              Hacking    31     17097

# %%
sexo=['H','M']

# %%
df_['sexo']=[sexo[np.random.randint(0,2)] for i in range(len(df['edad']))]
df_
# Out:
#            nombre         especialidad  edad  visistas sexo
# 0       SFDX Show             Hardware    33     14610    M
# 1     Sara Nogark     Edición de vídeo    32     23135    M
# 2    Nate Gentile         Programación    30     14429    H
# 3       Bettatech         Programación    33     20531    M
# 4  Antonio Sarosi  Sistemas Operativos    28     34024    H
# 5      Edgar Pons             Robótica    28     28923    H
# 6         s4vitar              Hacking    31     17097    M

# %% [markdown]
# ### explorando un data frame

# %%
df.head() #primeros 5 valores
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5      Edgar Pons             Robótica    29   143620    H

# %%
df.tail() #ultimos valores
# Out:
#            nombre         especialidad  edad  visitas sexo
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5      Edgar Pons             Robótica    29   143620    H
# 6         s4vitar              Hacking    28   132567    H

# %%
df.sample()
# Out:
#     nombre especialidad  old  visitas sexo
# 6  s4vitar      Hacking   28   132567    H

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre        7 non-null      object
#  1   especialidad  7 non-null      object
#  2   edad          7 non-null      int64
#  3   visitas       7 non-null      int64
#  4   sexo          7 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 336.0+ bytes

# %%
# df.describe()['edad']['max']
df.describe()
# Out:
#             edad        visitas
# count   7.000000       7.000000
# mean   29.428571  135033.142857
# std     1.272418   11590.990631
# min    28.000000  114175.000000
# 25%    28.500000  131431.500000
# 50%    29.000000  132567.000000
# 75%    30.500000  143082.500000
# max    31.000000  149462.000000

# %%
df.shape
# Out:
# (7, 5)

# %%
df.columns
# Out:
# Index(['nombre', 'especialidad', 'old', 'visitas', 'sexo'], dtype='object')

# %%
df.columns =['nombre', 'especialidad', 'old', 'visitas', 'sexo']

# %%
df.index
# Out:
# Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')

# %% [markdown]
# ### seleccion  de elementos (subset)

# %% [markdown]
# #### acceso mediant3e etiquetas

# %%
df.head()
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H

# %%
df[df['nombre'] == 'Nate Gentile'] ['especialidad']
# Out:
# 2    Programación
# Name: especialidad, dtype: object

# %%
df.head()
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H

# %%
df.iloc[0,0:2]
# Out:
# nombre          SFDX Show
# especialidad     Hardware
# Name: 0, dtype: object

# %%
df.loc[2,'especialidad':]
# Out:
# especialidad    Programación
# edad                      31
# visitas               142545
# sexo                       H
# Name: 2, dtype: object

# %% [markdown]
# ### Manipulacion de datos

# %% [markdown]
# ##### Cambiar indice

# %%
df
# Out:
#            nombre         especialidad  edad  visitas sexo
# 0       SFDX Show             Hardware    30   130855    H
# 1     Sara Nogark     Edición de vídeo    29   114175    M
# 2    Nate Gentile         Programación    31   142545    H
# 3       Bettatech         Programación    31   149462    H
# 4  Antonio Sarosi  Sistemas Operativos    28   132008    H
# 5      Edgar Pons             Robótica    29   143620    H
# 6         s4vitar              Hacking    28   132567    H

# %%
df_nuevo=df.set_index('nombre')
# df_nuevo=df.set_index('nombre',inplace=True)

# %%
df_nuevo
# Out:
#                        especialidad  edad  visitas sexo
# nombre
# SFDX Show                  Hardware    30   130855    H
# Sara Nogark        Edición de vídeo    29   114175    M
# Nate Gentile           Programación    31   142545    H
# Bettatech              Programación    31   149462    H
# Antonio Sarosi  Sistemas Operativos    28   132008    H
# Edgar Pons                 Robótica    29   143620    H
# s4vitar                     Hacking    28   132567    H

# %%
df.reset_index(inplace=True)

# %%
df_nuevo.loc[['Nate Gentile','s4vitar'],['edad','visitas']]
# Out:
#               edad  visitas
# nombre
# Nate Gentile    31   142545
# s4vitar         28   132567

# %% [markdown]
# ##### df.aplly()

# %%
df.select_dtypes(include='int64').apply(np.sqrt)
# Out:
#        edad     visitas
# 0  5.477226  361.738856
# 1  5.385165  337.897914
# 2  5.567764  377.551321
# 3  5.567764  386.603156
# 4  5.291503  363.329052
# 5  5.385165  378.972295
# 6  5.291503  364.097514

# %%
df['especialidad_m']=df['especialidad'].apply(lambda x: x.upper()) #title para volver

# %%
df
# Out:
#            nombre         especialidad  edad  visitas sexo  \
# 0       SFDX Show             HARDWARE    30   130855    H
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175    M
# 2    Nate Gentile         PROGRAMACIÓN    31   142545    H
# 3       Bettatech         PROGRAMACIÓN    31   149462    H
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008    H
# 5      Edgar Pons             ROBÓTICA    29   143620    H
# 6         s4vitar              HACKING    28   132567    H
#
#         especialidad_m
# 0             HARDWARE
# 1     EDICIÓN DE VÍDEO
# 2         PROGRAMACIÓN
# 3         PROGRAMACIÓN
# 4  SISTEMAS OPERATIVOS
# 5             ROBÓTICA
# 6              HACKING

# %%
df.drop('sexo', inplace=True, axis=1)

# %%
df
# Out:
#            nombre         especialidad  edad  visitas
# 0       SFDX Show             HARDWARE    30   130855
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175
# 2    Nate Gentile         PROGRAMACIÓN    31   142545
# 3       Bettatech         PROGRAMACIÓN    31   149462
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008
# 5      Edgar Pons             ROBÓTICA    29   143620
# 6         s4vitar              HACKING    28   132567

# %%
new_df=df.copy()

# %%
new_df.drop_duplicates('edad', keep='last')
# Out:
#        nombre  especialidad  edad  visitas
# 0   SFDX Show      HARDWARE    30   130855
# 3   Bettatech  PROGRAMACIÓN    31   149462
# 5  Edgar Pons      ROBÓTICA    29   143620
# 6     s4vitar       HACKING    28   132567

# %%
# df.nlargest(3,'visitas')
df.nlargest(len(df),'visitas')
# Out:
#            nombre         especialidad  edad  visitas
# 3       Bettatech         PROGRAMACIÓN    31   149462
# 5      Edgar Pons             ROBÓTICA    29   143620
# 2    Nate Gentile         PROGRAMACIÓN    31   142545
# 6         s4vitar              HACKING    28   132567
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008
# 0       SFDX Show             HARDWARE    30   130855
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175

# %%
df.sort_values(by = 'visitas')
# Out:
#            nombre         especialidad  edad  visitas
# 1     Sara Nogark     EDICIÓN DE VÍDEO    29   114175
# 0       SFDX Show             HARDWARE    30   130855
# 4  Antonio Sarosi  SISTEMAS OPERATIVOS    28   132008
# 6         s4vitar              HACKING    28   132567
# 2    Nate Gentile         PROGRAMACIÓN    31   142545
# 5      Edgar Pons             ROBÓTICA    29   143620
# 3       Bettatech         PROGRAMACIÓN    31   149462
